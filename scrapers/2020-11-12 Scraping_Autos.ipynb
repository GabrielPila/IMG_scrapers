# %%
# !pip install selenium
# !pip install selenium

# %%
from selenium import webdriver
import bs4
import urllib
import urllib.request
import time

# %%
driver = webdriver.Chrome(executable_path='chromedriver.exe')

# %%
totalCars = {}
i = 0
for page in range(1, 300):
    url = f'http://www.dautos.pe/anuncios.php?pag={page}&b=&Ciudad=&Vehiculo=&Marca=&Modelo=&Ano='
    driver.get(url)
    time.sleep(1.5)
    try:
        for row in range(1,9):
            for col in range(1,6):
                try:
                    obj_car = {}
                    linkCar = f'/html/body/div[5]/div/div/div[{row}]/div[{col}]/div/div/div/figure/div/div'
                    obj_car['page'] = page
                    try:
                        obj_car['carTexts'] = driver.find_element_by_xpath(f'{linkCar}/p[1]/a/strong').text
                    except:
                        obj_car['carTexts'] = ''
                    try:
                        obj_car['addLinks'] = driver.find_element_by_xpath(f'{linkCar}/p[1]/a').get_attribute('href')
                    except:
                        obj_car['addLinks'] = ''
                    try:
                        obj_car['carImage'] = driver.find_element_by_xpath(f'{linkCar}/a/img').get_attribute('src')
                    except:
                        obj_car['carImage'] = ''
                    try:
                        obj_car['imgNames'] = carImage.split('/')[-1]
                    except:
                        obj_car['imgNames'] = ''
                    try:
                        obj_car['carPrice'] = driver.find_element_by_xpath(f'{linkCar}/h4').text
                    except:
                        obj_car['carPrice'] = ''
                    try:
                        obj_car['location'] = driver.find_element_by_xpath(f'{linkCar}/p[2]').text
                    except:
                        obj_car['location'] = ''
                    try:
                        locaList = obj_car['location'].split(' ')
                    except:
                        locaList = ''
                    try:
                        obj_car['dep'], obj_car['prov'] = (locaList[0], '') if len(locaList) == 1 else (locaList[0], locaList[-1])
                    except:
                        obj_car['dep'], obj_car['prov'] = '', ''
                    print(obj_car)
                    totalCars[i] = obj_car
                    i+=1
                except: pass
#         buttonNext = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[11]/a')
#         buttonNext = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[13]/a')-
        buttonNext.click()
#         time.sleep(1.5)
    except: continue
# Out:
# {'page': 1, 'carTexts': '', 'addLinks': '', 'carImage': '', 'imgNames': 'margot75899-10112020-131417-pbFoto1.jpg', 'carPrice': '', 'location': '', 'dep': '', 'prov': ''}
# {'page': 1, 'carTexts': '', 'addLinks': '', 'carImage': '', 'imgNames': 'margot75899-10112020-131417-pbFoto1.jpg', 'carPrice': '', 'location': '', 'dep': '', 'prov': ''}
# {'page': 1, 'carTexts': '', 'addLinks': '', 'carImage': '', 'imgNames': 'margot75899-10112020-131417-pbFoto1.jpg', 'carPrice': '', 'location': '', 'dep': '', 'prov': ''}
# {'page': 1, 'carTexts': '', 'addLinks': '', 'carImage': '', 'imgNames': 'margot75899-10112020-131417-pbFoto1.jpg', 'carPrice': '', 'location': '', 'dep': '', 'prov': ''}
# {'page': 1, 'carTexts': '', 'addLinks': '', 'carImage': '', 'imgNames': 'margot75899-10112020-131417-pbFoto1.jpg', 'carPrice': '', 'location': '', 'dep': '', 'prov': ''}
# ...

# %%
df_cars = pd.DataFrame()
for key in totalCars:
    df_i = pd.DataFrame([totalCars[key]])
    df_cars = df_cars.append(df_i)

df_cars = df_cars.drop_duplicates()
df_cars = df_cars[df_cars['carImage']!='']

# %%
df_cars.to_csv('scrapeo_dautos_1.csv', index=False)

# %%
df_cars = pd.read_csv('scrapeo_dautos_1.csv')

# %%
df_cars

# %% [markdown]
# ### Otras pruebas de guardado

# %%
import csv
with open('innovators.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['carTexts', 'addLinks', 'carImage', 'imgNames', 'carPrice', 'location', 'dep', 'prov'])

# %%
# writer.writerow([1, "Linus Torvalds", "Linux Kernel"])
#     writer.writerow([2, "Tim Berners-Lee", "World Wide Web"])
#     writer.writerow(["SN", "Name", "Contribution"])
#     writer.writerow(["SN", "Name", "Contribution"])
#     writer.writerow([3, "Guido van Rossum", "Python Programming"])

# %%
# while True:
#     try:
#         page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[1]/a/strong').text
#     except:
#         try:
#             page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[3]/a/strong').text
#         except:
#             try:
#                 page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[4]/a/strong').text
#             except:
#                 try:
#                     page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[5]/a/strong').text
#                 except:
#                     try:
#                         page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[6]/a/strong').text
#                     except:
#                         try:
#                             page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[7]/a/strong').text
#                         except:
#                             try:
#                                 page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[8]/a/strong').text
#                             except:
#                                 try:
#                                     page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[9]/a/strong').text
#                                 except:
#                                     try:
#                                         page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[10]/a/strong').text
#                                     except:
#                                         try:
#                                             page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[7]/a/strong').text
#                                         except:
#                                             page = ''

# %%
buttonNext.text
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-282-ce978844b744> in <module>
# ----> 1 buttonNext.text
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
/html/body/div[5]/div/div/div[9]/div[10]/a/strong

# %%
try:
    page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[1]/a/strong').text
except:
    try:
        page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[3]/a/strong').text
    except:
        try:
            page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[4]/a/strong').text
        except:
            try:
                page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[5]/a/strong').text
            except:
                try:
                    page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[6]/a/strong').text
                except:
                    try:
                        page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[7]/a/strong').text
                    except:
                        try:
                            page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[8]/a/strong').text
                        except:
                            try:
                                page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[9]/a/strong').text
                            except:
                                try:
                                    page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[10]/a/strong').text
                                except:
                                    try:
                                        page = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[9]/div[7]/a/strong').text
                                    except:
                                        pass

# %%
page
# Out:
# '11'

# %%
len(totalCars_old2)
# Out:
# 594

# %%
totalCars_old2
# Out:
# {0: {'carTexts': 'COMPRO VEHICULOS SINIESTRADOS DE TODA MARCA',
#   'addLinks': 'http://www.dautos.pe/anuncio.php?%20%20COMPRO%20VEHICULOS%20SINIESTRADOS%20DE%20TODA%20%20MARCA&n=75945',
#   'carImage': 'http://www.dautos.pe/images/anuncios/fr/bancos%20kimberly75945-7112020-164610-pbFoto1.jpg',
#   'imgNames': 'margot75899-10112020-131417-pbFoto1.jpg',
#   'carPrice': 'Precio Conversable',
#   'location': 'CUSCO   ',
#   'dep': 'CUSCO',
#   'prov': ''},
#  1: {'carTexts': 'TOYOTA YARIS 2011',
#   'addLinks': 'http://www.dautos.pe/anuncio.php?TOYOTA%20YARIS%202011&n=75977',
#   'carImage': 'http://www.dautos.pe/images/anuncios/fr/bancos%20kimberly75977-7112020-172942-pbFoto1.jpg',
#   'imgNames': 'margot75899-10112020-131417-pbFoto1.jpg',
#   'carPrice': 'Precio Conversable',
#   'location': 'CUSCO   ',
#   'dep': 'CUSCO',
#   'prov': ''},
#  2: {'carTexts': 'MERCEDES BENZ SPRINTER 515 2019 MOD 2020',
# ...
